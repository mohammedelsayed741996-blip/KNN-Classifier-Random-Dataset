# %% [markdown]
# checking librares versions

# %%
import pandas as pd
import sklearn
import matplotlib
import seaborn as sns
import numpy as np

print(f"pandas version: {pd.__version__}")
print(f"scikit-learn version: {sklearn.__version__}")
print(f"matplotlib version: {matplotlib.__version__}")
print(f"seaborn version: {sns.__version__}")
print(f"numpy version: {np.__version__}")
# Out:
# pandas version: 1.3.4
# scikit-learn version: 1.0.1
# matplotlib version: 3.4.3
# seaborn version: 0.11.2
# numpy version: 1.20.3

# %%
import sys
# !{sys.executable} -m pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# INFO: pip is looking at multiple versions of mlxtend to determine which version is compatible with other requirements. This could take a while.
#   Using cached mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from mlxtend) (1.6.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from mlxtend) (1.20.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from mlxtend) (1.3.4)
# Collecting scikit-learn>=1.3.1 (from mlxtend)
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from mlxtend) (3.4.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\moham\anaconda3\envs\ml_bootcamp\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Using cached mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
# Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 1.8/9.3 MB 4.0 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 5.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 6.6 MB/s eta 0:00:01
#    --------------------- ------------------ 5.0/9.3 MB 6.6 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.3 MB 4.5 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.3 MB 4.5 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.3 MB 4.5 MB/s eta 0:00:01
#    --------------------------- ------------ 6.3/9.3 MB 3.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.3 MB 3.4 MB/s eta 0:00:01
#    ------------------------------ --------- 7.1/9.3 MB 3.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.3 MB 3.0 MB/s eta 0:00:01
#    --------------------------------- ------ 7.9/9.3 MB 2.9 MB/s eta 0:00:01
#    ------------------------------------ --- 8.4/9.3 MB 3.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, mlxtend
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
# Successfully installed mlxtend-0.23.4 scikit-learn-1.3.2

# %% [markdown]
# Importing the necessary libraries

# %%
from sklearn.datasets import make_blobs
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from mlxtend.plotting import plot_decision_regions
import time
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay
import numpy as np
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Generating the database

# %%
inputs, target = make_blobs(n_samples = 1000,
                            centers = [(-3, 3), (0, 0), (2, 2)],
                            random_state = 365)

# %%
inputs.shape, target.shape
# Out:
# ((1000, 2), (1000,))

# %%
data = pd.DataFrame(data = inputs, columns = ['Feature 1', 'Feature 2'])
data['Target'] = target
data
# Out:
#      Feature 1  Feature 2  Target
# 0     1.630460   2.094029       2
# 1    -2.811252   3.852241       0
# 2     0.501051   1.582531       2
# 3    -3.624112   3.325318       0
# 4    -3.278106   2.359416       0
# ..         ...        ...     ...
# 995  -4.412271   2.420197       0
# 996   0.398022  -0.847863       1
# 997  -0.588974   0.317711       1
# 998  -2.328593   4.957489       0
# 999  -0.400935  -0.185953       1
#
# [1000 rows x 3 columns]

# %% [markdown]
# plotting the database

# %%
knn_palette = sns.color_palette(['#000C1F', '#29757A', '#FF5050'])
knn_palette
# Out:
# [(0.0, 0.047058823529411764, 0.12156862745098039),
#  (0.1607843137254902, 0.4588235294117647, 0.47843137254901963),
#  (1.0, 0.3137254901960784, 0.3137254901960784)]

# %%
sns.set()

plt.figure(figsize = (16, 9))
sns.scatterplot(x = 'Feature 1', y = 'Feature 2',
                data = data,
                hue = 'Target', palette = knn_palette,
                markers = [',', '^', 'P'],
                style = 'Target',
                s = 100)
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
# Visualizing the distribution of the points

# %%
sns.set()

sns.jointplot(x = 'Feature 1', y = 'Feature 2',
              data = data,
              hue = 'Target',
              palette = knn_palette,
              height = 10,
              s = 100,
              legend = True);

# %% [markdown]
# creating a train-test-split

# %%
x_train, x_test, y_train, y_test = train_test_split(inputs, target,
                                                    test_size = 0.2,
                                                    random_state = 365,
                                                    stratify = target)

# %% [markdown]
# creating the model

# %%
clf = KNeighborsClassifier(n_neighbors = 30, weights = 'distance')
clf.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=30, weights='distance')

# %% [markdown]
# predicting a sample

# %%
feature_1 = -0.18
feature_2 = 3.2

# %%
clf.predict([[feature_1, feature_2]])
# Out:
# array([2])

# %%
neighbors = clf.kneighbors([[feature_1, feature_2]])
neighbors
# Out:
# (array([[0.27086818, 0.34749744, 0.40387913, 0.45668128, 0.57370524,
#          0.58002987, 0.6147827 , 0.62680551, 0.76674656, 0.77233172,
#          0.78175021, 0.84541382, 0.8741025 , 0.8769993 , 0.89014688,
#          0.91521046, 0.92223527, 0.99986243, 1.01649367, 1.0231371 ,
#          1.03996308, 1.04075309, 1.05202214, 1.05586882, 1.10512231,
#          1.14601178, 1.15303035, 1.16564948, 1.16938942, 1.16964811]]),
#  array([[336, 215, 679, 221, 690, 688, 269, 309, 543, 100,  79, 161, 708,
#          613, 216, 291, 561, 748, 516, 140, 514, 399,  25, 255, 431,   0,
#          386, 458,   3, 304]], dtype=int64))

# %% [markdown]
# visualizing the neighbors

# %%
sns.set()
plt.figure(figsize = (16, 9))

sns.scatterplot(x = x_train[:, 0], y = x_train[:, 1],
                hue = y_train,
                palette = knn_palette,
                markers = [',', '^', 'P'],
                style = y_train,
                s = 100,
                legend = True);

sns.scatterplot(x = [feature_1], y = [feature_2],
                style = [feature_2],
                markers = ['o'],
                s = 100,
                legend = False);

plot_x_train = []
plot_y_train = []

for i in neighbors[1]:
    plot_x_train.append(x_train[i, 0])
    plot_y_train.append(x_train[i, 1])
    
plt.scatter(plot_x_train,
            plot_y_train,
            s = 200, facecolors = 'none', edgecolors = 'r');

# %% [markdown]
# getting the parameters of the model

# %%
clf.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 30,
#  'p': 2,
#  'weights': 'distance'}

# %% [markdown]
# Drawing the decesion region

# %%
x_train.shape
# Out:
# (800, 2)

# %%
start = time.time()

plt.figure(figsize = (16, 9))

plot_decision_regions(X = x_train, y = y_train,
                      X_highlight = np.array([[feature_1, feature_2]]),
                      clf = clf,
                      markers = [',', '^', 'P'],
                      colors = '#000c1f,#29757a,#ff5050',
                      scatter_kwargs = {'s':100, 'edgecolor':'white', 'alpha':1},
                      legend = 0)

plt.xlabel('Feature 1')
plt.ylabel('Feature 2');

end = time.time()

print(f'Time elapsed: {round(end - start, 1)} seconds')
# Out:
# Time elapsed: 22.8 seconds

# %% [markdown]
# Getting error rates of a set of models

# %%
error_uniform = []
error_distance = []

k_range = range(1, 51)

for k in k_range:
    
    clf = KNeighborsClassifier(n_neighbors = k, weights = 'uniform')
    clf.fit(x_train, y_train)
    predictions = clf.predict(x_test)
    error_uniform.append(1 - accuracy_score(y_test, predictions))
    
    clf = KNeighborsClassifier(n_neighbors = k, weights = 'distance')
    clf.fit(x_train, y_train)
    predictions = clf.predict(x_test)
    error_distance.append(1 - accuracy_score(y_test, predictions))

# %% [markdown]
# Plotting the error rates as a function of the number of neighbors

# %%
plt.figure(figsize = (16, 9))
plt.plot(k_range, error_uniform, c = 'blue', linestyle = 'solid',
         marker = 'o', markerfacecolor = 'red', label = 'Error uniform')

plt.plot(k_range, error_distance, c = 'green', linestyle = 'dashed',
         marker = 'o', markerfacecolor = 'red', label = 'Error distance')

plt.legend()

plt.xlabel('K-value')
plt.ylabel('Error rate');

# %% [markdown]
# Choosing a set of parameters to test

# %%
parameters = {'n_neighbors':range(1, 51),
              'weights':['uniform', 'distance']}

# %% [markdown]
# Create an instance of the GridSearchCV class

# %%
grid_search = GridSearchCV(estimator = KNeighborsClassifier(),
                           param_grid = parameters,
                           scoring = 'accuracy')

grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 51),
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
grid_search.best_params_
# Out:
# {'n_neighbors': 10, 'weights': 'uniform'}

# %%
clf=grid_search.best_estimator_
clf
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
grid_search.best_score_
# Out:
# 0.9512499999999999

# %% [markdown]
# Make predictions on the test dataset

# %%
y_test_pred = clf.predict(x_test)
y_test_pred.shape
# Out:
# (200,)

# %% [markdown]
# Construct the confusion matrix

# %%
ConfusionMatrixDisplay.from_predictions(
    y_test, y_test_pred,
    labels = clf.classes_,
    cmap = 'magma'
);

# %% [markdown]
# Print out the classification report

# %%
print(classification_report(y_test, y_test_pred, target_names = ['0', '1', '2']))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99        67
#            1       0.97      0.93      0.95        67
#            2       0.93      0.98      0.96        66
#
#     accuracy                           0.96       200
#    macro avg       0.97      0.97      0.96       200
# weighted avg       0.97      0.96      0.97       200
